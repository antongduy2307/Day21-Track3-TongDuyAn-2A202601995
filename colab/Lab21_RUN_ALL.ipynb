# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/antongduy2307/Day21-Track3-TongDuyAn-2A202601995.git"
if not os.path.exists("Day21-Track3-TongDuyAn-2A202601995"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-TongDuyAn-2A202601995")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 8b71c10
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.89s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 5.53MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 46.8MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 66.6MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 96.6MB/s]
#
# tokenizer.json: downloading bytes:   4% 777k/20.0M [00:00<00:15, 1.23MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 8.61MB/s,  615kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 27.6MB/s, 1.97MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.39MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 4.56MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 21.9MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-TongDuyAn-2A202601995/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 133MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   0% 11.1M/9.32G [00:00<09:39, 16.1MB/s]
# Downloading bytes:   1% 118M/9.32G [00:00<00:51, 178MB/s,  131MB/s  ]
# Downloading bytes:   3% 324M/9.32G [00:01<00:43, 205MB/s,  296MB/s  ]
# Downloading bytes:   4% 404M/9.32G [00:02<00:39, 226MB/s,  219MB/s  ]
# Downloading bytes:   6% 584M/9.32G [00:02<00:29, 296MB/s,  281MB/s  ]
# Downloading bytes:   7% 665M/9.32G [00:03<00:37, 230MB/s,  261MB/s  ]
# Downloading bytes:  16% 1.53G/9.32G [00:06<00:28, 277MB/s,  263MB/s  ]
# Downloading bytes:  24% 2.20G/9.32G [00:10<00:38, 187MB/s,  198MB/s  ]
# Downloading bytes:  24% 2.24G/9.32G [00:10<00:54, 130MB/s,  127MB/s  ]
# Downloading bytes:  25% 2.34G/9.32G [00:11<00:59, 117MB/s,  130MB/s  ]
# Downloading bytes:  25% 2.37G/9.32G [00:11<00:55, 125MB/s,  122MB/s  ]
# Downloading bytes:  26% 2.41G/9.32G [00:12<01:01, 112MB/s,  106MB/s  ]
# Downloading bytes:  32% 2.96G/9.32G [00:14<00:24, 260MB/s,  281MB/s  ]
# Downloading bytes:  32% 3.00G/9.32G [00:14<00:39, 161MB/s,  260MB/s  ]
# Downloading bytes:  32% 3.02G/9.32G [00:15<00:41, 154MB/s,  161MB/s  ]
# Downloading bytes:  34% 3.15G/9.32G [00:15<00:35, 173MB/s,  157MB/s  ]
# Downloading bytes:  40% 3.76G/9.32G [00:18<00:20, 266MB/s,  283MB/s  ]
# Downloading bytes:  45% 4.15G/9.32G [00:20<00:21, 240MB/s,  268MB/s  ]
# Downloading bytes:  52% 4.86G/9.32G [00:23<00:20, 215MB/s,  309MB/s  ]
# Downloading bytes:  53% 4.91G/9.32G [00:23<00:31, 138MB/s,  182MB/s  ]
# Downloading bytes:  54% 5.01G/9.32G [00:24<00:40, 108MB/s,  103MB/s  ]
# Downloading bytes:  54% 5.03G/9.32G [00:25<00:48, 87.7MB/s, 84.1MB/s  ]
# Downloading bytes:  55% 5.12G/9.32G [00:25<00:41, 102MB/s,  100MB/s  ]
# Downloading bytes:  56% 5.20G/9.32G [00:26<00:36, 112MB/s,  105MB/s  ]
# Downloading bytes:  57% 5.32G/9.32G [00:28<00:45, 88.7MB/s, 81.1MB/s  ]
# Downloading bytes:  57% 5.34G/9.32G [00:28<00:42, 93.6MB/s, 88.7MB/s  ]
# Downloading bytes:  58% 5.38G/9.32G [00:28<00:39, 101MB/s, 92.7MB/s  ]
# Downloading bytes:  63% 5.84G/9.32G [00:30<00:19, 179MB/s,  205MB/s  ]
# Downloading bytes:  70% 6.50G/9.32G [00:33<00:11, 250MB/s,  308MB/s  ]
# Downloading bytes:  75% 7.03G/9.32G [00:34<00:07, 314MB/s,  301MB/s  ]
# Reconstructing (incomplete total...):  59% 5.53G/9.32G [00:46<01:12, 52.4MB/s,  132MB/s  ]
# Downloading bytes:  83% 7.70G/9.32G [00:49<00:05, 321MB/s,  313MB/s  ]
# Downloading bytes:  86% 8.02G/9.32G [00:54<00:06, 193MB/s,  164MB/s  ]
# Reconstructing (incomplete total...):  73% 6.83G/9.32G [00:55<00:24, 103MB/s, 75.3MB/s  ]
# Reconstructing (incomplete total...):  74% 6.90G/9.32G [00:55<00:23, 103MB/s,  103MB/s  ]
# Reconstructing (incomplete total...):  76% 7.09G/9.32G [00:56<00:17, 125MB/s,  103MB/s  ]
# Reconstructing (incomplete total...):  79% 7.38G/9.32G [00:57<00:14, 135MB/s,  125MB/s  ]
# Reconstructing (incomplete total...):  82% 7.65G/9.32G [00:58<00:09, 181MB/s,  135MB/s  ]
# Reconstructing (incomplete total...):  83% 7.76G/9.32G [00:58<00:08, 180MB/s,  181MB/s  ]
# Reconstructing (incomplete total...):  84% 7.82G/9.32G [00:59<00:08, 172MB/s,  180MB/s  ]
# Reconstructing (incomplete total...):  87% 8.11G/9.32G [01:00<00:06, 196MB/s,  172MB/s  ]
# Reconstructing (incomplete total...):  89% 8.31G/9.32G [01:01<00:04, 229MB/s,  196MB/s  ]
# Reconstructing (incomplete total...):  91% 8.49G/9.32G [01:03<00:05, 141MB/s,  229MB/s  ]
# Reconstructing (incomplete total...):  92% 8.59G/9.32G [01:03<00:04, 155MB/s,  141MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:03<01:03, 63.99s/it]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [01:07<00:00, 177MB/s,  155MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:07<00:00, 33.88s/it]
# Download complete: 100% 8.05G/8.05G [01:07<00:00, 193MB/s,  193MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:07<00:00, 119MB/s,  193MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:07<00:00, 137MB/s,  177MB/s  ]
# Loading weights: 100% 426/426 [00:34<00:00, 12.25it/s]
#   [(a) base + naive prompt/target] batch 1/13     14s elapsed  ~  174s left
#   [(a) base + naive prompt/target] batch 2/13     27s elapsed  ~  148s left
#   [(a) base + naive prompt/target] batch 3/13     39s elapsed  ~  130s left
#   [(a) base + naive prompt/target] batch 4/13     51s elapsed  ~  115s left
#   [(a) base + naive prompt/target] batch 5/13     64s elapsed  ~  102s left
#   [(a) base + naive prompt/target] batch 6/13     76s elapsed  ~   89s left
#   [(a) base + naive prompt/target] batch 7/13     88s elapsed  ~   76s left
#   [(a) base + naive prompt/target] batch 8/13    100s elapsed  ~   63s left
#   [(a) base + naive prompt/target] batch 9/13    112s elapsed  ~   50s left
#   [(a) base + naive prompt/target] batch 10/13    124s elapsed  ~   37s left
#   [(a) base + naive prompt/target] batch 11/13    136s elapsed  ~   25s left
#   [(a) base + naive prompt/target] batch 12/13    149s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    161s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 161s
#   [(a) base + naive prompt/regression] batch 1/4      5s elapsed  ~   16s left
#   [(a) base + naive prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(a) base + naive prompt/regression] batch 3/4     20s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     28s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 28s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3216ms
#   [(b) base + optimized prompt/target] batch 1/13      4s elapsed  ~   47s left
#   [(b) base + optimized prompt/target] batch 2/13      8s elapsed  ~   43s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   39s left
#   [(b) base + optimized prompt/target] batch 4/13     15s elapsed  ~   35s left
#   [(b) base + optimized prompt/target] batch 5/13     19s elapsed  ~   31s left
#   [(b) base + optimized prompt/target] batch 6/13     24s elapsed  ~   28s left
#   [(b) base + optimized prompt/target] batch 7/13     27s elapsed  ~   23s left
#   [(b) base + optimized prompt/target] batch 8/13     31s elapsed  ~   19s left
#   [(b) base + optimized prompt/target] batch 9/13     35s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     39s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     43s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     47s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     50s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 50s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   14s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(b) base + optimized prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 27s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  1007ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3216.10454546,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 1007.4438551199979,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 385s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1070.93it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:30<00:00, 13.78it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-TongDuyAn-2A202601995/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 7017.48 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 35423.54 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.382', 'grad_norm': '2.5', 'learning_rate': '8.83e-05', 'entropy': '1.032', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.77', 'epoch': '0.7111'}
# {'loss': '0.1409', 'grad_norm': '0.6198', 'learning_rate': '6.434e-05', 'entropy': '0.2667', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9576', 'epoch': '1'}
# {'loss': '0.02877', 'grad_norm': '0.9372', 'learning_rate': '3.566e-05', 'entropy': '0.0414', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9873', 'epoch': '1.356'}
# {'loss': '0.01727', 'grad_norm': '0.3461', 'learning_rate': '1.17e-05', 'entropy': '0.02235', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9933', 'epoch': '1.711'}
# {'loss': '0.02465', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01603', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9961', 'epoch': '2'}
# {'train_runtime': '919.4', 'train_samples_per_second': '0.489', 'train_steps_per_second': '0.033', 'train_loss': '0.6262', 'epoch': '2'}
# 100% 30/30 [15:19<00:00, 30.65s/it]
# train 920s  final loss 0.6262
# saved -> /content/Day21-Track3-TongDuyAn-2A202601995/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 919.8,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6262,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 979s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1135.13it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:30<00:00, 14.08it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1098.42it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:30<00:00, 14.10it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6973.10 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45900.70 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.777', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8289', 'grad_norm': '1.854', 'learning_rate': '8.83e-05', 'entropy': '0.9419', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8393', 'epoch': '0.7111'}
# {'loss': '0.1485', 'grad_norm': '1.327', 'learning_rate': '6.434e-05', 'entropy': '0.288', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9591', 'epoch': '1'}
# {'loss': '0.04148', 'grad_norm': '0.9191', 'learning_rate': '3.566e-05', 'entropy': '0.06473', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9866', 'epoch': '1.356'}
# {'loss': '0.02194', 'grad_norm': '0.2229', 'learning_rate': '1.17e-05', 'entropy': '0.03245', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9909', 'epoch': '1.711'}
# {'loss': '0.02416', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02348', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9945', 'epoch': '2'}
# {'train_runtime': '779.3', 'train_samples_per_second': '0.616', 'train_steps_per_second': '0.038', 'train_loss': '0.5381', 'epoch': '2'}
# 100% 30/30 [12:59<00:00, 25.98s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1314.01it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:30<00:00, 13.91it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8628.99 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 37468.47 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '915', 'train_samples_per_second': '0.525', 'train_steps_per_second': '0.033', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:14<00:00, 30.50s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 934.66it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.27it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10487.62 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45885.08 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '976.9', 'train_samples_per_second': '0.491', 'train_steps_per_second': '0.031', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:16<00:00, 32.56s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6262 | 919.8 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5381 | 779.6 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 915.4 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 977.3 | 7.09 |
#
# -- NB4 ok in 2833s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 902.87it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.63it/s]
#   [ft/target] batch 1/13      6s elapsed  ~   76s left
#   [ft/target] batch 2/13     12s elapsed  ~   66s left
#   [ft/target] batch 3/13     17s elapsed  ~   57s left
#   [ft/target] batch 4/13     22s elapsed  ~   49s left
#   [ft/target] batch 5/13     28s elapsed  ~   44s left
#   [ft/target] batch 6/13     33s elapsed  ~   38s left
#   [ft/target] batch 7/13     38s elapsed  ~   32s left
#   [ft/target] batch 8/13     42s elapsed  ~   26s left
#   [ft/target] batch 9/13     47s elapsed  ~   21s left
#   [ft/target] batch 10/13     52s elapsed  ~   16s left
#   [ft/target] batch 11/13     57s elapsed  ~   10s left
#   [ft/target] batch 12/13     63s elapsed  ~    5s left
#   [ft/target] batch 13/13     68s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 68s
#   [ft/regression] batch 1/4     10s elapsed  ~   31s left
#   [ft/regression] batch 2/4     21s elapsed  ~   21s left
#   [ft/regression] batch 3/4     28s elapsed  ~    9s left
#   [ft/regression] batch 4/4     40s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 40s
# fine-tune: {'target': 0.97, 'regression': 0.611111111111111, 'format': 1.0, 'latency_ms': 1356.1397176399803, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3216.1 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 1007.4 | 50 |
# | (c) LoRA fine-tune | 0.97 | 0.6111 | 1.0 | 1356.1 | 50 |
# FAILED
#  - general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1042.45it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.44it/s]
#   [attn_only/target] batch 1/13      3s elapsed  ~   39s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   40s left
#   [attn_only/target] batch 3/13     10s elapsed  ~   35s left
#   [attn_only/target] batch 4/13     14s elapsed  ~   31s left
#   [attn_only/target] batch 5/13     17s elapsed  ~   28s left
#   [attn_only/target] batch 6/13     21s elapsed  ~   24s left
#   [attn_only/target] batch 7/13     24s elapsed  ~   20s left
#   [attn_only/target] batch 8/13     27s elapsed  ~   17s left
#   [attn_only/target] batch 9/13     30s elapsed  ~   13s left
#   [attn_only/target] batch 10/13     34s elapsed  ~   10s left
#   [attn_only/target] batch 11/13     37s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     40s elapsed  ~    3s left
#   [attn_only/target] batch 13/13     44s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 44s
# attn_only: target=0.970  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1078.64it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.56it/s]
#   [wrong_lr/target] batch 1/13     19s elapsed  ~  224s left
#   [wrong_lr/target] batch 2/13     38s elapsed  ~  209s left
#   [wrong_lr/target] batch 3/13     57s elapsed  ~  189s left
#   [wrong_lr/target] batch 4/13     76s elapsed  ~  171s left
#   [wrong_lr/target] batch 5/13     95s elapsed  ~  152s left
#   [wrong_lr/target] batch 6/13    114s elapsed  ~  133s left
#   [wrong_lr/target] batch 7/13    133s elapsed  ~  114s left
#   [wrong_lr/target] batch 8/13    152s elapsed  ~   95s left
#   [wrong_lr/target] batch 9/13    172s elapsed  ~   76s left
#   [wrong_lr/target] batch 10/13    190s elapsed  ~   57s left
#   [wrong_lr/target] batch 11/13    210s elapsed  ~   38s left
#   [wrong_lr/target] batch 12/13    229s elapsed  ~   19s left
#   [wrong_lr/target] batch 13/13    248s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 248s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 956.29it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.72it/s]
#   [qlora/target] batch 1/13      7s elapsed  ~   79s left
#   [qlora/target] batch 2/13     14s elapsed  ~   75s left
#   [qlora/target] batch 3/13     20s elapsed  ~   67s left
#   [qlora/target] batch 4/13     27s elapsed  ~   61s left
#   [qlora/target] batch 5/13     34s elapsed  ~   54s left
#   [qlora/target] batch 6/13     40s elapsed  ~   47s left
#   [qlora/target] batch 7/13     46s elapsed  ~   40s left
#   [qlora/target] batch 8/13     53s elapsed  ~   33s left
#   [qlora/target] batch 9/13     60s elapsed  ~   27s left
#   [qlora/target] batch 10/13     66s elapsed  ~   20s left
#   [qlora/target] batch 11/13     73s elapsed  ~   13s left
#   [qlora/target] batch 12/13     79s elapsed  ~    7s left
#   [qlora/target] batch 13/13     86s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 86s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.97 | 1.0 | 1356.1 | 50 |
# | attn_only | 0.97 | 1.0 | 878.6 | 50 |
# | wrong_lr | 0.0 | 0.0 | 4957.0 | 50 |
# | qlora | 0.94 | 1.0 | 1725.4 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |
#
# -- NB5 ok in 649s
#
# ----------------------------------------
# stage timings
#   nb1        19s  (0.3 min)
#   nb2       385s  (6.4 min)
#   nb3       979s  (16.3 min)
#   nb4      2833s  (47.2 min)
#   nb5       649s  (10.8 min)
#   total    4865s (81.1 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.54s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [  ok  ] full eval set used                               50 target items
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.765
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.205, regression Δ -0.147)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 24 passed · 1 warnings · 2 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 52
# drwxr-xr-x  2 root root  4096 Aug 21 05:39 .
# drwxr-xr-x 15 root root  4096 Aug 21 04:18 ..
# -rw-r--r--  1 root root   433 Aug 21 05:39 autopsy.json
# -rw-r--r--  1 root root   511 Aug 21 04:25 baselines_frozen.json
# -rw-r--r--  1 root root     0 Aug 21 04:17 .gitkeep
# -rw-r--r--  1 root root   592 Aug 21 04:18 mask_proof.json
# -rw-r--r--  1 root root 13677 Aug 21 05:39 qualitative.json
# -rw-r--r--  1 root root  1099 Aug 21 05:28 runs.csv
# -rw-r--r--  1 root root   277 Aug 21 04:18 template_check.json
# -rw-r--r--  1 root root   115 Aug 21 04:18 token_stats.json
# -rw-r--r--  1 root root   806 Aug 21 05:31 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,919.8,12.01,0.6262,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,779.6,12.02,0.5381,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,915.4,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,977.3,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.7578,
#       "format": 0.0,
#       "latency_ms": 3216.1,
#       "n": 50
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.765,
#       "regression": 0.7578,
#       "format": 1.0,
#       "latency_ms": 1007.4,
#       "n": 50
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.97,
#       "regression": 0.6111,
#       "format": 1.0,
#       "latency_ms": 1356.1,
#       "n": 50
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.20499999999999996,
#     "regression_delta": -0.14666666666666672
#   },
#   "valid_trace_rate": 0.0
# }

# %%
# @title 5. Đóng gói kết quả để tải về (nộp bài)
# Colab VM sẽ mất khi ngắt kết nối — tải zip này về máy NGAY sau khi chạy xong.
import shutil, subprocess, pathlib

MSSV = "2A202601995"
stem = f"lab21_{MSSV}"
root = pathlib.Path("/content") / stem
if root.exists():
    shutil.rmtree(root)
root.mkdir(parents=True)

# Option A trong rubric.md: REPORT.md + results/ + adapters/correct/ + notebooks/
shutil.copytree("results", root / "results")
if pathlib.Path("adapters/correct").exists():
    shutil.copytree("adapters/correct", root / "adapters" / "correct",
                    ignore=shutil.ignore_patterns("checkpoint-*"))
shutil.copytree("submission", root / "submission")
shutil.copytree("notebooks", root / "notebooks")

zip_path = shutil.make_archive(f"/content/{stem}", "zip", "/content", stem)
print("zip:", zip_path)
subprocess.run(["ls", "-lh", zip_path])

from google.colab import files
files.download(zip_path)
# Out:
# zip: /content/lab21_2A202601995.zip
